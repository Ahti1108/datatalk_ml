# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Features
#
# For the rest of the homework, you'll need to use the features from the previous homework with additional two 'neighbourhood_group' and 'room_type'. So the whole feature set will be set as follows:
#
# * `neighbourhood_group',
# * `room_type`,
# * `latitude`,
# * `longitude`,
# * `price`,
# * `minimum_nights`,
# * `number_of_reviews`,
# * `reviews_per_month`,
# * `calculated_host_listings_count`,
# * `availability_365`
#
# Select only them and fill in the missing values with 0.

# %%
cols = ['neighbourhood_group', 'room_type', 'latitude', 'longitude', 'price', 'minimum_nights', 
         'number_of_reviews', 'reviews_per_month', 'calculated_host_listings_count', 'availability_365']
df = pd.read_csv('nyc_airbnb.csv', usecols=cols)
df.head()
# Out:
#   neighbourhood_group  latitude  longitude        room_type  price  \
# 0            Brooklyn  40.64749  -73.97237     Private room    149
# 1           Manhattan  40.75362  -73.98377  Entire home/apt    225
# 2           Manhattan  40.80902  -73.94190     Private room    150
# 3            Brooklyn  40.68514  -73.95976  Entire home/apt     89
# 4           Manhattan  40.79851  -73.94399  Entire home/apt     80
#
#    minimum_nights  number_of_reviews  reviews_per_month  \
# 0               1                  9               0.21
# 1               1                 45               0.38
# 2               3                  0                NaN
# 3               1                270               4.64
# 4              10                  9               0.10
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 1                               2               355
# 2                               1               365
# 3                               1               194
# 4                               1                 0

# %%
df.isnull().sum()
# Out:
# neighbourhood_group                   0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
df = df.fillna(0)
df.isnull().sum()
# Out:
# neighbourhood_group               0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %% [markdown]
# ## Question 1
#
# What is the most frequent observation (mode) for the column 'neighbourhood_group'?

# %%
df.neighbourhood_group.mode()
# Out:
# 0    Manhattan
# dtype: object

# %% [markdown]
# ### Split the data
#
# * Split your data in train/val/test sets, with 60%/20%/20% distribution.
# * Use Scikit-Learn for that (the train_test_split function) and set the seed to 42.
# * Make sure that the target value ('price') is not in your dataframe.

# %%
above_average = df.price >= 152
df.price = above_average.astype(int)

# %%
df.head()
# Out:
#   neighbourhood_group  latitude  longitude        room_type  price  \
# 0            Brooklyn  40.64749  -73.97237     Private room      0
# 1           Manhattan  40.75362  -73.98377  Entire home/apt      1
# 2           Manhattan  40.80902  -73.94190     Private room      0
# 3            Brooklyn  40.68514  -73.95976  Entire home/apt      0
# 4           Manhattan  40.79851  -73.94399  Entire home/apt      0
#
#    minimum_nights  number_of_reviews  reviews_per_month  \
# 0               1                  9               0.21
# 1               1                 45               0.38
# 2               3                  0               0.00
# 3               1                270               4.64
# 4              10                  9               0.10
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 1                               2               355
# 2                               1               365
# 3                               1               194
# 4                               1                 0

# %%
df.price.value_counts()
# Out:
# 0    33992
# 1    14903
# Name: price, dtype: int64

# %%
df_full_train, df_test = train_test_split(df, test_size = 0.2, random_state=42)
df_train, df_val = train_test_split(df_full_train, test_size=0.25, random_state=42)

# %%
len(df_train), len(df_val), len(df_test)
# Out:
# (29337, 9779, 9779)

# %%
len(df_val) / (len(df_train) + len(df_val) + len(df_test))
# Out:
# 0.2

# %%
df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)

# %%
y_train = df_train.price.values
y_val = df_val.price.values
y_test = df_test.price.values

# %%
del df_train['price']
del df_val['price']
del df_test['price']

# %% [markdown]
# ## Question 2
#
# * Create the correlation matrix for the numerical features of your train dataset.
#     * In a correlation matrix, you compute the correlation coefficient between every pair of features in the dataset.
# * What are the two features that have the biggest correlation in this dataset?

# %%
df_corr = df_train.corr()
df_corr
# Out:
#                                 latitude  longitude  minimum_nights  \
# latitude                        1.000000   0.080301        0.027441
# longitude                       0.080301   1.000000       -0.060660
# minimum_nights                  0.027441  -0.060660        1.000000
# number_of_reviews              -0.006246   0.055084       -0.076020
# reviews_per_month              -0.007159   0.134642       -0.120703
# calculated_host_listings_count  0.019375  -0.117041        0.118647
# availability_365               -0.005891   0.083666        0.138901
#
#                                 number_of_reviews  reviews_per_month  \
# latitude                                -0.006246          -0.007159
# longitude                                0.055084           0.134642
# minimum_nights                          -0.076020          -0.120703
# number_of_reviews                        1.000000           0.590374
# reviews_per_month                        0.590374           1.000000
# calculated_host_listings_count          -0.073167          -0.048767
# availability_365                         0.174477           0.165376
#
#                                 calculated_host_listings_count  \
# latitude                                              0.019375
# longitude                                            -0.117041
# minimum_nights                                        0.118647
# number_of_reviews                                    -0.073167
# reviews_per_month                                    -0.048767
# calculated_host_listings_count                        1.000000
# availability_365                                      0.225913
#
#                                 availability_365
# latitude                               -0.005891
# longitude                               0.083666
# minimum_nights                          0.138901
# number_of_reviews                       0.174477
# reviews_per_month                       0.165376
# calculated_host_listings_count          0.225913
# availability_365                        1.000000

# %% [markdown]
# ### Make price binary
#
# * We need to turn the price variable from numeric into binary.
# * Let's create a variable `above_average` which is 1 if the price is above (or equal to) 152.

# %% [markdown]
# ## Question 3
#
# * Calculate the mutual information score with the (binarized) price for the two categorical variables that we have. Use the training set only.
# * Which of these two variables has bigger score?
# * Round it to 2 decimal digits using `round(score, 2)`

# %%
df_full_train.dtypes
# Out:
# neighbourhood_group                object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int32
# minimum_nights                      int64
# number_of_reviews                   int64
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# dtype: object

# %%
df_full_train.columns
# Out:
# Index(['neighbourhood_group', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365'],
#       dtype='object')

# %%
df_full_train.head()
# Out:
#       neighbourhood_group  latitude  longitude        room_type  price  \
# 32645            Brooklyn  40.71577  -73.95530  Entire home/apt      1
# 23615           Manhattan  40.84917  -73.94048     Private room      0
# 31183            Brooklyn  40.68993  -73.95947     Private room      0
# 29260            Brooklyn  40.68427  -73.93118  Entire home/apt      0
# 7275               Queens  40.74705  -73.89564     Private room      0
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# 32645               3                 11               0.87
# 23615               2                  2               0.16
# 31183               2                  0               0.00
# 29260               3                 87               4.91
# 7275                5                 13               0.25
#
#        calculated_host_listings_count  availability_365
# 32645                               1                 1
# 23615                               1                 0
# 31183                               2                 0
# 29260                               1               267
# 7275                                1                 0

# %%
from sklearn.metrics import mutual_info_score

# %%
categorical = ['neighbourhood_group', 'room_type']

# %%
numerical = ['latitude', 'longitude', 'minimum_nights', 'number_of_reviews', 'reviews_per_month',
            'calculated_host_listings_count', 'availability_365']

# %%
mutual_info_score(df_full_train.neighbourhood_group, df_full_train.price)
# Out:
# 0.0462226506346477

# %%
mutual_info_score(df_full_train.room_type, df_full_train.price)
# Out:
# 0.14238980766429526

# %%
def mutual_info_price_score(series):
    return mutual_info_score(series, df_full_train.price)

# %%
df_full_train[categorical].apply(mutual_info_price_score).round(2)
# Out:
# neighbourhood_group    0.05
# room_type              0.14
# dtype: float64

# %% [markdown]
# ## Question 4
#
# * Now let's train a logistic regression
# * Remember that we have two categorical variables in the data. Include them using one-hot encoding.
# * Fit the model on the training dataset.
#     * To make sure the results are reproducible across different versions of Scikit-Learn, fit the model with these parameters:
#     * `model = LogisticRegression(solver='lbfgs', C=1.0, random_state=42)`
# * Calculate the accuracy on the validation dataset and round it to 2 decimal digits.

# %%
from sklearn.feature_extraction import DictVectorizer

# %%
train_dicts = df_train[categorical + numerical].to_dict(orient='records')

# %%
dv = DictVectorizer(sparse=False)

# %%
dv.fit(train_dicts)
# Out:
# DictVectorizer(dtype=<class 'numpy.float64'>, separator='=', sort=True,
#                sparse=False)

# %%
dv.get_feature_names()
# Out:
# ['availability_365',
#  'calculated_host_listings_count',
#  'latitude',
#  'longitude',
#  'minimum_nights',
#  'neighbourhood_group=Bronx',
#  'neighbourhood_group=Brooklyn',
#  'neighbourhood_group=Manhattan',
#  'neighbourhood_group=Queens',
#  'neighbourhood_group=Staten Island',
#  'number_of_reviews',
#  'reviews_per_month',
#  'room_type=Entire home/apt',
#  'room_type=Private room',
#  'room_type=Shared room']

# %%
X_train = dv.transform(train_dicts)

# %%
val_dicts = df_val[numerical + categorical].to_dict(orient='records')

# %%
X_val = dv.transform(val_dicts)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression(solver='lbfgs', random_state=42, max_iter=900)

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=900,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=42, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
model.predict_proba(X_train)
# Out:
# array([[0.68041785, 0.31958215],
#        [0.86002854, 0.13997146],
#        [0.89521642, 0.10478358],
#        ...,
#        [0.90346622, 0.09653378],
#        [0.98215859, 0.01784141],
#        [0.39533994, 0.60466006]])

# %%
y_pred = model.predict_proba(X_val)[:, 1]

# %%
y_pred
# Out:
# array([0.02886042, 0.59559439, 0.42611385, ..., 0.11399177, 0.03462159,
#        0.52933489])

# %%
price_decision = (y_pred > 0.5)

# %%
df_val[price_decision]
# Out:
#      neighbourhood_group  latitude  longitude        room_type  \
# 1               Brooklyn  40.68498  -73.96618  Entire home/apt
# 4              Manhattan  40.76075  -73.99893  Entire home/apt
# 6              Manhattan  40.73243  -74.00932  Entire home/apt
# 7              Manhattan  40.80630  -73.96268  Entire home/apt
# 9              Manhattan  40.80861  -73.94574  Entire home/apt
# 10             Manhattan  40.80549  -73.96393  Entire home/apt
# 12              Brooklyn  40.62795  -73.96281  Entire home/apt
# 13             Manhattan  40.77822  -73.98016  Entire home/apt
# 14             Manhattan  40.79633  -73.94819  Entire home/apt
# 19             Manhattan  40.77359  -73.94865  Entire home/apt
# 20             Manhattan  40.77085  -73.94933  Entire home/apt
# 23             Manhattan  40.78853  -73.97510  Entire home/apt
# 24             Manhattan  40.73679  -73.98177  Entire home/apt
# 25             Manhattan  40.76213  -73.94893  Entire home/apt
# 27             Manhattan  40.73064  -73.99937  Entire home/apt
# 32             Manhattan  40.78171  -73.94617  Entire home/apt
# 38             Manhattan  40.80107  -73.96065  Entire home/apt
# 39             Manhattan  40.74415  -73.99483  Entire home/apt
# 41             Manhattan  40.73280  -74.00845  Entire home/apt
# 44             Manhattan  40.86856  -73.92623  Entire home/apt
# 53             Manhattan  40.76088  -73.98971  Entire home/apt
# 55              Brooklyn  40.68857  -73.98668  Entire home/apt
# 56             Manhattan  40.71944  -73.99396  Entire home/apt
# 65              Brooklyn  40.71697  -73.94227  Entire home/apt
# 66             Manhattan  40.70411  -74.00909  Entire home/apt
# 68             Manhattan  40.72087  -73.99022  Entire home/apt
# 69             Manhattan  40.72958  -73.98569  Entire home/apt
# 71             Manhattan  40.72854  -73.98434  Entire home/apt
# 77             Manhattan  40.73248  -74.00053  Entire home/apt
# 81             Manhattan  40.75979  -73.96079  Entire home/apt
# ...                  ...       ...        ...              ...
# 9695           Manhattan  40.76216  -73.96195  Entire home/apt
# 9696            Brooklyn  40.69833  -73.93463  Entire home/apt
# 9702           Manhattan  40.73114  -73.98869  Entire home/apt
# 9705           Manhattan  40.72184  -73.99440  Entire home/apt
# 9714           Manhattan  40.72280  -73.98562  Entire home/apt
# 9715           Manhattan  40.76476  -73.98871  Entire home/apt
# 9716           Manhattan  40.75103  -73.98349  Entire home/apt
# 9718           Manhattan  40.81301  -73.94502  Entire home/apt
# 9720           Manhattan  40.76156  -73.99342  Entire home/apt
# 9723           Manhattan  40.73246  -74.00215  Entire home/apt
# 9726           Manhattan  40.77858  -73.95059  Entire home/apt
# 9730           Manhattan  40.79118  -73.97091  Entire home/apt
# 9732            Brooklyn  40.68282  -73.93289  Entire home/apt
# 9736           Manhattan  40.75843  -73.96265  Entire home/apt
# 9737            Brooklyn  40.69455  -73.95144  Entire home/apt
# 9739           Manhattan  40.76744  -73.95901  Entire home/apt
# 9741           Manhattan  40.72428  -73.98748  Entire home/apt
# 9743           Manhattan  40.79950  -73.96965  Entire home/apt
# 9745           Manhattan  40.75861  -73.96359  Entire home/apt
# 9749           Manhattan  40.76413  -73.99301  Entire home/apt
# 9753           Manhattan  40.75114  -73.99843  Entire home/apt
# 9754           Manhattan  40.80622  -73.93875  Entire home/apt
# 9758            Brooklyn  40.60245  -73.98140  Entire home/apt
# 9761           Manhattan  40.76574  -73.98018  Entire home/apt
# 9762           Manhattan  40.75169  -73.97174  Entire home/apt
# 9763           Manhattan  40.73525  -73.98074  Entire home/apt
# 9768           Manhattan  40.80177  -73.95710  Entire home/apt
# 9770           Manhattan  40.73833  -73.98943  Entire home/apt
# 9774           Manhattan  40.75974  -73.98924  Entire home/apt
# 9778           Manhattan  40.81882  -73.94680  Entire home/apt
#
#       minimum_nights  number_of_reviews  reviews_per_month  \
# 1                 14                  4               0.11
# 4                 30                  0               0.00
# 6                  4                  1               0.03
# 7                  7                  2               0.05
# 9                  3                123               1.73
# 10                 3                 10               0.38
# 12                 3                  6               0.71
# 13                 1                  0               0.00
# 14                30                  3               0.16
# 19                 1                  1               0.25
# 20                 2                  1               0.38
# 23                 4                  5               0.23
# 24                30                104               1.51
# 25                 4                  9               3.38
# 27                 7                  0               0.00
# 32                30                  6               0.15
# 38                 1                  1               0.02
# 39                 3                  1               1.00
# 41                 2                  1               0.04
# 44                 1                 12               2.98
# 53                30                  1               0.26
# 55                30                  7               0.15
# 56                 2                 47               2.19
# 65                 2                  1               1.00
# 66                 1                  0               0.00
# 68                31                 59               0.63
# 69                 3                 10               3.00
# 71                 2                  1               0.02
# 77                 1                 29               1.72
# 81                 1                 42               1.06
# ...              ...                ...                ...
# 9695              30                 12               0.26
# 9696               1                  5               1.90
# 9702               5                 44               2.77
# 9705              30                 92               1.09
# 9714              23                  1               0.02
# 9715               7                  0               0.00
# 9716               2                 10               0.23
# 9718               4                  9               0.94
# 9720              45                  1               0.48
# 9723              10                  4               0.06
# 9726               4                  2               0.05
# 9730              30                  1               0.59
# 9732               2                 74               1.65
# 9736               1                  0               0.00
# 9737               2                 12               0.59
# 9739               4                  2               0.06
# 9741               1                  1               0.03
# 9743               4                  2               0.06
# 9745              30                  0               0.00
# 9749               2                  0               0.00
# 9753               8                  3               1.05
# 9754               2                  0               0.00
# 9758               2                  3               1.03
# 9761               2                  0               0.00
# 9762               2                  2               0.06
# 9763              14                  0               0.00
# 9768               8                  9               0.18
# 9770               2                  2               0.70
# 9774               4                  2               0.14
# 9778               1                  1               0.02
#
#       calculated_host_listings_count  availability_365
# 1                                  2               343
# 4                                 18               365
# 6                                  1                 0
# 7                                  1                 0
# 9                                  3               248
# 10                                 1                 0
# 12                                 3               173
# 13                                 1                 0
# 14                                 1               212
# 19                                 5               365
# 20                                 1                 0
# 23                                 1               157
# 24                                 4               333
# 25                                 1                33
# 27                                 1                 0
# 32                                15               225
# 38                                 1                 0
# 39                                 1                60
# 41                                 1                 0
# 44                                 2               357
# 53                                 1               331
# 55                                21               360
# 56                                 1                34
# 65                                 3               318
# 66                                 1                 9
# 68                                 1                27
# 69                                 1                 7
# 71                                 1                 0
# 77                                 1                14
# 81                                 1               357
# ...                              ...               ...
# 9695                              34               331
# 9696                               1               264
# 9702                               1               179
# 9705                               1               106
# 9714                               1                 0
# 9715                               1                 5
# 9716                               1                 0
# 9718                               1               245
# 9720                               1                56
# 9723                               1                 3
# 9726                               1                 0
# 9730                               1                 3
# 9732                               1               333
# 9736                               1                 0
# 9737                               1               332
# 9739                               1                 0
# 9741                               1                 0
# 9743                               1                 0
# 9745                             232               149
# 9749                               3                 3
# 9753                               1                39
# 9754                               1                 3
# 9758                               1                16
# 9761                               4               229
# 9762                               4                 0
# 9763                               1                 0
# 9768                               1               111
# 9770                               1               166
# 9774                               1                 5
# 9778                               1                 0
#
# [2839 rows x 9 columns]

# %%
y_val
# Out:
# array([0, 0, 1, ..., 0, 0, 0])

# %%
price_decision.astype(int)
# Out:
# array([0, 1, 0, ..., 0, 0, 1])

# %%
(y_val == price_decision).mean()
# Out:
# 0.790878412925657

# %%
df_pred = pd.DataFrame()
df_pred['probability'] = y_pred
df_pred['prediction'] = price_decision.astype(int)
df_pred['actual'] = y_val

# %%
df_pred.head()
# Out:
#    probability  prediction  actual
# 0     0.028860           0       0
# 1     0.595594           1       0
# 2     0.426114           0       1
# 3     0.075114           0       0
# 4     0.811493           1       1

# %%
df_pred['correct'] = df_pred.prediction == df_pred.actual

# %%
df_pred.head()
# Out:
#    probability  prediction  actual  correct
# 0     0.028860           0       0     True
# 1     0.595594           1       0    False
# 2     0.426114           0       1    False
# 3     0.075114           0       0     True
# 4     0.811493           1       1     True

# %%
round(df_pred.correct.mean(), 2)
# Out:
# 0.79

# %% [markdown]
# ## Question 5
#
# * We have 9 features: 7 numerical features and 2 categorical.
# * Let's find the least useful one using the feature elimination technique.
# * Train a model with all these features (using the same parameters as in Q4).
# * Now exclude each feature from this set and train a model without it. Record the accuracy for each model.
# * For each feature, calculate the difference between the original accuracy and the accuracy without the feature.
# * Which of following feature has the smallest difference?
#     * `neighbourhood_group`
#     * `room_type`
#     * `number_of_reviews`
#     * `reviews_per_month`
#
# Note: the difference doesn't have to be positive
